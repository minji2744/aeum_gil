# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd

newneek = pd.read_csv("/content/drive/MyDrive/data/newneek/newneek_211002_onlylink.csv")

# %%
newneek.shape
# Out:
# (2821, 6)

# %%
display(newneek)
# Out:
#       기사id  ...                                                 원문
# 0        0  ...    https://www.yna.co.kr/view/AKR20210929177100083
# 1        0  ...  https://www.yna.co.kr/view/AKR2021092911590050...
# 2        0  ...  https://terms.naver.com/entry.naver?docId=5144...
# 3        1  ...  https://go.seoul.co.kr/news/newsView.php?id=20...
# 4        1  ...  https://www.hankookilbo.com/News/Read/A2021092...
# ...    ...  ...                                                ...
# 2816   847  ...  https://www.reuters.com/article/us-harvard-adm...
# 2817   847  ...  https://www.nytimes.com/2018/06/15/us/harvard-...
# 2818   847  ...            https://news.joins.com/article/11775777
# 2819   848  ...    https://www.yna.co.kr/view/AKR20191002086700076
# 2820   848  ...             https://ko.wikipedia.org/wiki/언론_자유_지수
#
# [2821 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
newneek.groupby(['카테고리']).count()
# Out:
#         기사id   제목   날짜  요약문   원문
# 카테고리
# 경제       291  291  291  291  291
# 국내정치     495  495  495  495  495
# 노동·일     141  141  141  141  141
# 세계       783  783  783  783  783
# 여성       105  105  105  105  105
# 코로나19    262  262  262  262  262
# 테크       117  117  117  117  117
# 피자스테이션    37   37   37   37   37
# 환경       140  140  140  140  140

# %%
ref = [x.split(".")[1] for x in newneek['원문']]

# %%
newneek['ref'] = ref

# %%
display(ref)
# Out:
# ['yna',
#  'yna',
#  'naver',
#  'seoul',
#  'hankookilbo',
#  'hani',
#  'joongang',
#  'joongang',
#  'hani',
#  'kbs',
#  'khan',
#  'kbs',
#  'khan',
#  'hankyung',
#  'mk',
#  'mk',
#  'naver',
#  'jtbc',
#  'yna',
#  'khan',
#  'news1',
#  'donga',
#  'hankyung',
#  'asiae',
#  'nocutnews',
#  'seoul',
#  'hankookilbo',
#  'etoday',
#  'kbs',
#  'segye',
#  'hankookilbo',
#  'hankookilbo',
#  'hankookilbo',
#  'naver',
#  'nocutnews',
#  'img',
#  'hani',
#  'kbs',
#  'hani',
#  'hankyung',
#  'ytn',
#  'econovill',
#  'index',
#  'joins',
#  'donga',
#  'jtbc',
#  'youtube',
#  'munhwa',
#  'yna',
#  'netflix',
#  'joongang',
#  'imbc',
#  'chosun',
#  'hankookilbo',
#  'co',
#  'dongascience',
#  'hani',
#  'com/view/?id=NISX20210914_0001583851',
#  'kbs',
#  'sbs',
#  'mt',
#  'hyundai',
#  'seoul',
#  'com/view/?id=NISX20210912_0001580745',
#  'ifixit',
#  'assembly',
#  'newsian',
#  'sisain',
#  'chosun',
#  'jtbc',
#  'joongang',
#  'bbc',
#  'kukinews',
#  'sbs',
#  'imbc',
#  'hankyung',
#  'edaily',
#  'chosun',
#  'co',
#  'mk',
#  'hani',
#  'ytn',
#  'hankookilbo',
#  'chosun',
#  'heraldcorp',
#  'sbs',
#  'sbs',
#  'joongang',
#  'asiae',
#  'imbc',
#  'kbs',
#  'seoul',
#  'kbs',
#  'seoul',
#  'hankyung',
#  'yna',
#  'sisain',
#  'hani',
#  'hani',
#  'un',
#  'hankookilbo',
#  'khan',
#  'notion',
#  'news1',
#  'mk',
#  'labortoday',
#  'khan',
#  'imbc',
#  'voakorea',
#  'hankookilbo',
#  'huffingtonpost',
#  'hani',
#  'hankyung',
#  'donga',
#  'joongang',
#  'kbs',
#  'news1',
#  'nytimes',
#  'donga',
#  'chosun',
#  'chosun',
#  'seoul',
#  'seoul',
#  'mk',
#  'newsverse',
#  'hani',
#  'hankookilbo',
#  'donga',
#  'hankookilbo',
#  'joongang',
#  'hankookilbo',
#  'kdca',
#  'hani',
#  'hani',
#  'hankookilbo',
#  'ytn',
#  'seoul',
#  'ebs',
#  'yna',
#  'mohw',
#  'news1',
#  'yna',
#  'hani',
#  'upinews',
#  'hankyung',
#  'kbs',
#  'chosun',
#  'khan',
#  'independent',
#  'assembly',
#  'assembly',
#  'yna',
#  'khan',
#  'hankyung',
#  'hankookilbo',
#  'kbs',
#  'joongang',
#  'hankookilbo',
#  'mt',
#  'chosun',
#  'mk',
#  'chosun',
#  'youtube',
#  'instagram',
#  'paralympic',
#  'instagram',
#  'youtube',
#  'netflix',
#  'instagram',
#  'youtube',
#  'netflix',
#  'com/armlessarcher',
#  'com/tokyo-2020/en/paralympics/news/usa-paralympian-matt-stutzman-always-wanted-to-be-the-best-archer-in-the-world',
#  'segye',
#  'khan',
#  'hani',
#  'hani',
#  'hani',
#  'mk',
#  'hani',
#  'hani',
#  'hani',
#  'koreaes',
#  'hani',
#  'chosun',
#  'segye',
#  'sedaily',
#  'esquirekorea',
#  'sedaily',
#  'etoday',
#  'co',
#  'seoul',
#  'kukinews',
#  'kbs',
#  'yna',
#  'yna',
#  'yna',
#  'yna',
#  'hani',
#  'be/svHTOYL7sDw',
#  'oopy',
#  'sbs',
#  'yna',
#  'seoul',
#  'yna',
#  'hani',
#  'hani',
#  'joongang',
#  'hani',
#  'sbs',
#  'joongang',
#  'hani',
#  'sbs',
#  'yna',
#  'imbc',
#  'hankookilbo',
#  'sbs',
#  'kbs',
#  'nocutnews',
#  'hankookilbo',
#  'yna',
#  'yna',
#  'jtbc',
#  'ytn',
#  'news1',
#  'yna',
#  'kbs',
#  'joongang',
#  'kdca',
#  'mfds',
#  'mt',
#  'news1',
#  'chosun',
#  'hankookilbo',
#  'hankookilbo',
#  'mk',
#  'hani',
#  'nocutnews',
#  'hani',
#  'hani',
#  'hankookilbo',
#  'com/view/?id=NISX20210823_0001556491',
#  'donga',
#  'segye',
#  'yna',
#  'donga',
#  'ytn',
#  'mediatoday',
#  'naver',
#  'mediatoday',
#  'donga',
#  'naver',
#  'yna',
#  'yna',
#  'bloomberg',
#  'khan',
#  'donga',
#  'yna',
#  'news1',
#  'donga',
#  'mk',
#  'mk',
#  'sedaily',
#  'com/view/?id=NISX20210820_0001555244',
#  'hankyung',
#  'mt',
#  'hani',
#  'bbc',
#  'sisain',
#  'donga',
#  'yna',
#  'chosun',
#  'nocutnews',
#  'kbs',
#  'news1',
#  'news1',
#  'news1',
#  'yna',
#  'wowtv',
#  'yna',
#  'mt',
#  'hankyung',
#  'sbs',
#  'dongascience',
#  'etnews',
#  'chosun',
#  'donga',
#  'sedaily',
#  'hankyung',
#  'hankookilbo',
#  'news1',
#  'mk',
#  'chosun',
#  'asiae',
#  'yna',
#  'yna',
#  'joins',
#  'seoul',
#  'news1',
#  'mergepoint',
#  'hankyung',
#  'hankookilbo',
#  'hankookilbo',
#  'joins',
#  'hani',
#  'hankookilbo',
#  'yna',
#  'khan',
#  'voltron',
#  'hani',
#  'yna',
#  'kbs',
#  'hankookilbo',
#  'news1',
#  'chosun',
#  'yna',
#  'hani',
#  'news1',
#  'joins',
#  'hani',
#  'news1',
#  'who',
#  'khan',
#  'ipcc',
#  'yna',
#  'khan',
#  'kbs',
#  'hani',
#  'hani',
#  'hankookilbo',
#  'korea',
#  'donga',
#  'economist',
#  'com/view/?id=NISX20210809_0001541797&cID=10101&pID=10100',
#  'yna',
#  'naver',
#  'khan',
#  'khan',
#  'chosun',
#  'donga',
#  'com/view/?id=NISX20210808_0001541353',
#  'hani',
#  'reuters',
#  'apple',
#  'huffingtonpost',
#  'mk',
#  'nocutnews',
#  'korea',
#  'korea',
#  'hankookilbo',
#  'instagram',
#  'com/en/athletes/kohei-uchimura',
#  'instagram',
#  'washingtonpost',
#  'sedaily',
#  'com/article/2020-tokyo-olympics-acts-of-kindness-sportsmanship-f7484946288e2a078b2a1f9eccbc1232',
#  'instagram',
#  'instagram',
#  'instagram',
#  'instagram',
#  'joins',
#  'chosun',
#  'nocutnews',
#  'naver',
#  'chosun',
#  'joins',
#  'hani',
#  'yna',
#  'kbs',
#  'yna',
#  'korean',
#  'sbs',
#  'yna',
#  'hani',
#  'kbs',
#  'hani',
#  'stuff',
#  'yna',
#  'ytn',
#  'jtbc',
#  'com/view/?id=NISX20210420_0001413064',
#  'mk',
#  'kdca',
#  'yna',
#  'dongascience',
#  'mk',
#  'co',
#  'chosun',
#  'huffingtonpost',
#  'instagram',
#  'bbc',
#  'mk',
#  'sbs',
#  'hani',
#  'hankookilbo',
#  'yna',
#  'ytn',
#  'hani',
#  'joins',
#  'mk',
#  'yna',
#  'news1',
#  'ytn',
#  'seoul',
#  'joins',
#  'joins',
#  'yna',
#  'yna',
#  'reuters',
#  'khan',
#  'chosun',
#  'yna',
#  'news1',
#  'yna',
#  'npr',
#  'kmib',
#  'joins',
#  'npr',
#  'khan',
#  'news1',
#  'jejusori',
#  'yna',
#  'hankookilbo',
#  'joins',
#  'imbc',
#  'joins',
#  'donga',
#  'theguardian',
#  'yna',
#  'hani',
#  'yna',
#  'yna',
#  'yna',
#  'joins',
#  'hani',
#  'imbc',
#  'chosun',
#  'yna',
#  'joins',
#  'seoul',
#  'hankookilbo',
#  'chosun',
#  'yna',
#  'khan',
#  'segye',
#  'hankookilbo',
#  'yna',
#  'sbs',
#  'khan',
#  'dongascience',
#  'reuters',
#  'joins',
#  'pstatic',
#  'chosun',
#  'chosun',
#  'yna',
#  'news1',
#  'edaily',
#  'asiae',
#  'hani',
#  'yna',
#  'jtbc',
#  'yna',
#  'newspenguin',
#  'instagram',
#  'instagram',
#  'youtube',
#  'youtube',
#  'youtube',
#  'youtube',
#  'youtube',
#  'youtube',
#  'youtube',
#  'instagram',
#  'youtube',
#  'instagram',
#  'instagram',
#  'instagram',
#  'stibee',
#  'instagram',
#  'sedaily',
#  'enewstoday',
#  'khan',
#  'yna',
#  'kbs',
#  'khan',
#  'img',
#  'imbc',
#  'joins',
#  'seoul',
#  'etnews',
#  'president',
#  'hankyung',
#  'co',
#  'nytimes',
#  'yna',
#  'huffingtonpost',
#  'hankookilbo',
#  'hankyung',
#  'com/view/?id=NISX20210709_0001506848',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'yna',
#  'hankyung',
#  'khan',
#  'donga',
#  'donga',
#  'khan',
#  'hani',
#  'yna',
#  'jtbc',
#  'yna',
#  'khan',
#  'com/view/?id=NISX20210525_0001452337',
#  'news1',
#  'mk',
#  'joins',
#  'fsc',
#  'sbs',
#  'hankookilbo',
#  'hani',
#  'joins',
#  'joins',
#  'fnnews',
#  'sbs',
#  'huffingtonpost',
#  'yna',
#  'hani',
#  'joins',
#  'hani',
#  'nocutnews',
#  'hani',
#  'com/view/?id=NISX20210701_0001496988',
#  'hankookilbo',
#  'ee/zgd3',
#  'joins',
#  'naver',
#  'yna',
#  'sbs',
#  'news1',
#  'joins',
#  'news1',
#  'ytn',
#  'hani',
#  'heraldcorp',
#  'africanews',
#  'yna',
#  'kr/archives/183102',
#  'joins',
#  'joins',
#  'ytn',
#  'hani',
#  'joins',
#  'mk',
#  'chosun',
#  'com/view/?id=NISX20210621_0001483515',
#  'joins',
#  'ytn',
#  'hankyung',
#  'joins',
#  'yna',
#  'joins',
#  'washingtonpost',
#  'imbc',
#  'yna',
#  'bbc',
#  'khan',
#  'joins',
#  'fcbayern',
#  'donga',
#  'com/dw_sports/status/1407292741529309187',
#  'yna',
#  'yna',
#  'yna',
#  'naver',
#  'bbc',
#  'yna',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'naver',
#  'hani',
#  'hankyung',
#  'chosun',
#  'hani',
#  'joins',
#  'hani',
#  'yna',
#  'go',
#  'hankookilbo',
#  'yna',
#  'joins',
#  'yna',
#  'donga',
#  'mk',
#  'com/view/?id=NISX20210617_0001480387',
#  'chosun',
#  'khan',
#  'kr/articles/labor/nhiscall',
#  'chosun',
#  'donga',
#  'khan',
#  'khan',
#  'newscloud',
#  'hani',
#  'sbs',
#  'mk',
#  'hani',
#  'voakorea',
#  'yna',
#  'yna',
#  'seoul',
#  'imbc',
#  'yna',
#  'news1',
#  'kbs',
#  'chosun',
#  'chosun',
#  'mk',
#  'hankookilbo',
#  'news1',
#  'mk',
#  'bbc',
#  'hankyung',
#  'hani',
#  'segye',
#  'joins',
#  'hankookilbo',
#  'joins',
#  'news1',
#  'jtbc',
#  'joins',
#  'youngnong',
#  'huffingtonpost',
#  'mk',
#  'yna',
#  'chosun',
#  'mk',
#  'com/view/?id=NISX20210531_0001459649',
#  'mt',
#  'yna',
#  'nocutnews',
#  'amc',
#  'joins',
#  'bbc',
#  'mt',
#  'khan',
#  'sbs',
#  'hani',
#  'khan',
#  'yna',
#  'hani',
#  'huffingtonpost',
#  'kbs',
#  'yna',
#  'kbs',
#  'yna',
#  'yna',
#  'yna',
#  'hankookilbo',
#  'joins',
#  'hankookilbo',
#  'news1',
#  'khan',
#  'mediatoday',
#  'kmib',
#  'fnnews',
#  'typeform',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'edaily',
#  'hani',
#  'sciencetimes',
#  'newspenguin',
#  'newspenguin',
#  'yna',
#  'imbc',
#  'imbc',
#  'sbs',
#  'hani',
#  'hankookilbo',
#  'fnnews',
#  'kyongbuk',
#  'yna',
#  'nocutnews',
#  'humanrights',
#  'notion',
#  'hankyung',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'donga',
#  'jtbc',
#  'news1',
#  'hankookilbo',
#  'kbs',
#  'joins',
#  'theguardian',
#  'sportsseoul',
#  'kbs',
#  'kbs',
#  'joins',
#  'hankookilbo',
#  'hankookilbo',
#  'hankyung',
#  'chosun',
#  'sbs',
#  'jtbc',
#  'com/view/?id=NISX20210526_0001453814',
#  'hankookilbo',
#  'donga',
#  'yna',
#  'naver',
#  'joins',
#  'sedaily',
#  'seoul',
#  'news1',
#  'joins',
#  'news1',
#  'mk',
#  'sedaily',
#  'hankookilbo',
#  'yna',
#  'yna',
#  'naver',
#  'yna',
#  'khan',
#  'yna',
#  'chosun',
#  'news1',
#  'hankyung',
#  'com/view/?id=NISX20210414_0001406994',
#  'donga',
#  'molit',
#  'com/',
#  'yna',
#  'hankookilbo',
#  'nocutnews',
#  'donga',
#  'twimg',
#  'yna',
#  'sbs',
#  'joins',
#  'joins',
#  'joins',
#  'hani',
#  'com/news',
#  'yna',
#  'bbc',
#  'joins',
#  'voakorea',
#  'yna',
#  'yna',
#  'kbs',
#  'seoul',
#  'hankyung',
#  'm-i',
#  'donga',
#  'hankookilbo',
#  'ytn',
#  'khan',
#  'naver',
#  'nytimes',
#  'cnn',
#  'chosun',
#  'chosun',
#  'hankookilbo',
#  'nocutnews',
#  'khan',
#  'co:443/class/',
#  'hankookilbo',
#  'nocutnews',
#  'hankookilbo',
#  'hankyung',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'imbc',
#  'joins',
#  'hankyung',
#  'hani',
#  'hani',
#  'segye',
#  'com/view/?id=NISX20210504_0001430384',
#  'nocutnews',
#  'hankookilbo',
#  'nocutnews',
#  'hani',
#  'idaegu',
#  'joins',
#  'co',
#  'news1',
#  'khan',
#  'yna',
#  'news1',
#  'hankookilbo',
#  'news1',
#  'daumcdn',
#  'naver',
#  'chosun',
#  'yna',
#  'naver',
#  'yna',
#  'yna',
#  'asiae',
#  'ytn',
#  'joins',
#  'joins',
#  'hani',
#  'hankookilbo',
#  'hankyung',
#  'hankyung',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'chosun',
#  'sbs',
#  'hankookilbo',
#  'wikimedia',
#  'jtbc',
#  'mk',
#  'hankyung',
#  'chosun',
#  'hani',
#  'khan',
#  'mt',
#  'kwdi',
#  'yna',
#  'joins',
#  'hani',
#  'chosun',
#  'com/wp-content/uploads/2019/08/balticstatesmaps350',
#  'whereig',
#  'bbc',
#  'hankookilbo',
#  'news1',
#  'yna',
#  'hankookilbo',
#  'joins',
#  'be/rdy3xRgKefQ',
#  'hani',
#  'com/view/?id=NISX20210416_0001409737',
#  'joins',
#  'voakorea',
#  'yna',
#  'hankyung',
#  'hankyung',
#  'news1',
#  'sedaily',
#  'joins',
#  'com/ar_detail/view',
#  'yna',
#  'khan',
#  'khan',
#  'huffingtonpost',
#  'typeform',
#  'ytn',
#  'greenpeace',
#  'yna',
#  'hankookilbo',
#  'yna',
#  'hankookilbo',
#  'hankyung',
#  'apple',
#  'yna',
#  'hankyung',
#  'joins',
#  'chosun',
#  'coindeskkorea',
#  'news1',
#  'edaily',
#  'joins',
#  'chosun',
#  'joins',
#  'news1',
#  'yna',
#  'sedaily',
#  'hankookilbo',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'kmib',
#  'joins',
#  'naver',
#  'chosun',
#  'typeform',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'hankookilbo',
#  'yna',
#  'hankookilbo',
#  'yna',
#  'mk',
#  'sedaily',
#  'mt',
#  'hometax',
#  'newsis',
#  'yna',
#  'typeform',
#  'nec',
#  'yna',
#  'seoul',
#  'yna',
#  'chosun',
#  'womentimes',
#  'news1',
#  'stop',
#  'joins',
#  'etoday',
#  'mk',
#  'khan',
#  'mt',
#  'bloter',
#  'cryptokitties',
#  'stibee',
#  'stibee',
#  'stibee',
#  'stibee',
#  'nocutnews',
#  'sedaily',
#  'joins',
#  'com/view/?id=NISX20210325_0001382466',
#  'bbc',
#  'khan',
#  'bbc',
#  ...]

# %%
newneek.head()
# Out:
#    기사id   카테고리  ...                                                 원문          ref
# 0     0    NaN  ...    https://www.yna.co.kr/view/AKR20210929177100083          yna
# 1     0    NaN  ...  https://www.yna.co.kr/view/AKR2021092911590050...          yna
# 2     0    NaN  ...  https://terms.naver.com/entry.naver?docId=5144...        naver
# 3     1  코로나19  ...  https://go.seoul.co.kr/news/newsView.php?id=20...        seoul
# 4     1  코로나19  ...  https://www.hankookilbo.com/News/Read/A2021092...  hankookilbo
#
# [5 rows x 7 columns]

# %%
ref_df = newneek[['기사id', 'ref']].groupby(['ref']).count()

# %%
ref_df.head()
# Out:
#                 기사id
# ref
# africanews         1
# ai/                1
# ajunews            3
# amc                1
# apmresearchlab     1

# %%
plt.figure(figsize=(20,20))
ref_df = ref_df[ref_df['기사id']>30]
ref_df.plot(kind='bar')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
newneek['ref'].nunique()
# Out:
# 293

# %%
len(ref_df)
# Out:
# 19

# %%
ref_df.index
# Out:
# Index(['chosun', 'donga', 'hani', 'hankookilbo', 'hankyung', 'imbc', 'joins',
#        'kbs', 'khan', 'mk', 'mt', 'naver', 'news1', 'nocutnews', 'sbs',
#        'seoul', 'stibee', 'yna', 'ytn'],
#       dtype='object', name='ref')

# %%
ref_df['기사id'].apply(int).sum()
# Out:
# 2128
